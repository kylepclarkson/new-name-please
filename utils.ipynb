# %%
fp = "../.data/nlp/us_people_names.txt"

# %%
import csv
names = []
with open(fp) as file:
    reader = csv.reader(file)
    names = [row[3] for row in reader]

# %%
names[:4]
# Out:
# ['name', 'Elsie', 'Edward', 'William']

# %%
names = names[1:]

# %%
names = [name.lower() for name in names]

# %%
names[:10]
# Out:
# ['elsie',
#  'edward',
#  'william',
#  'robert',
#  'annie',
#  'katie',
#  'alma',
#  'thelma',
#  'ellen',
#  'rebecca']

# %%
len(names)
# Out:
# 5552452

# %%
unique_names = list(set(names))

# %%
len(unique_names)
# Out:
# 29828

# %%
unique_names[-5:]
# Out:
# ['shterna', 'wm', 'kamren', 'izak', 'gary']

# %%
names[-5:]
# Out:
# ['dalton', 'dexter', 'dominick', 'jesse', 'kaleb']

# %%
unique_names.sort()

# %%
unique_names
# Out:
# ['aaban',
#  'aadan',
#  'aadarsh',
#  'aaden',
#  'aadhya',
#  'aadi',
#  'aadil',
#  'aadin',
#  'aadit',
#  'aaditya',
#  'aadya',
#  'aadyn',
#  'aahan',
#  'aahana',
#  'aahil',
#  'aaiden',
#  'aaima',
#  'aakash',
#  'aalayah',
#  'aaleah',
#  'aaleyah',
#  'aalia',
#  'aaliah',
#  'aalijah',
#  'aaliya',
#  'aaliyah',
#  'aaliyha',
#  'aalliyah',
#  'aalyah',
#  'aalyiah',
#  'aamina',
#  'aaminah',
#  'aamir',
#  'aamira',
#  'aamiyah',
#  'aanchal',
#  'aanika',
#  'aaniya',
#  'aaniyah',
#  'aanya',
#  'aaradhya',
#  'aaralyn',
#  'aaralynn',
#  'aarav',
#  'aaren',
#  'aarian',
#  'aariana',
#  'aaric',
#  'aarika',
#  'aarin',
#  'aarion',
#  'aariyah',
#  'aariz',
#  'aarna',
#  'aarnav',
#  'aarohi',
#  'aaron',
#  'aaronjames',
#  'aaronjoshua',
#  'aaronmichael',
#  'aarron',
#  'aarti',
#  'aarush',
#  'aarushi',
#  'aarya',
#  'aaryan',
#  'aaryn',
#  'aasha',
#  'aashi',
#  'aashna',
#  'aashritha',
#  'aasia',
#  'aasim',
#  'aasiyah',
#  'aastha',
#  'aayan',
# ...

# %%
import random

valset = random.sample(unique_names, 1828)
trainset = [name for name in unique_names if name not in valset]

# %%
len(valset)
# Out:
# 1828

# %%
len(trainset)
# Out:
# 28000

# %%
trainset
# Out:
# ['aaban',
#  'aadan',
#  'aadarsh',
#  'aaden',
#  'aadhya',
#  'aadi',
#  'aadil',
#  'aadin',
#  'aaditya',
#  'aadya',
#  'aadyn',
#  'aahan',
#  'aahana',
#  'aahil',
#  'aaiden',
#  'aaima',
#  'aakash',
#  'aalayah',
#  'aaleah',
#  'aaleyah',
#  'aalia',
#  'aaliah',
#  'aalijah',
#  'aaliya',
#  'aaliyah',
#  'aaliyha',
#  'aalliyah',
#  'aalyah',
#  'aalyiah',
#  'aaminah',
#  'aamir',
#  'aamira',
#  'aamiyah',
#  'aanchal',
#  'aanika',
#  'aaniya',
#  'aaniyah',
#  'aanya',
#  'aaradhya',
#  'aaralyn',
#  'aaralynn',
#  'aarav',
#  'aaren',
#  'aarian',
#  'aariana',
#  'aarika',
#  'aarin',
#  'aarion',
#  'aariyah',
#  'aariz',
#  'aarnav',
#  'aarohi',
#  'aaron',
#  'aaronjames',
#  'aaronjoshua',
#  'aaronmichael',
#  'aarron',
#  'aarti',
#  'aarush',
#  'aarushi',
#  'aarya',
#  'aaryn',
#  'aasha',
#  'aashi',
#  'aashna',
#  'aashritha',
#  'aasia',
#  'aasim',
#  'aasiyah',
#  'aastha',
#  'aayan',
#  'aayden',
#  'aayla',
#  'aayush',
#  'aayushi',
#  'ab',
# ...

# %%
valset
# Out:
# ['tynisa',
#  'calib',
#  'abelina',
#  'karisma',
#  'mariadelourdes',
#  'hokulani',
#  'cova',
#  'jacquelina',
#  'awais',
#  'nayshawn',
#  'penina',
#  'deneisha',
#  'neven',
#  'debanhi',
#  'cloud',
#  'atif',
#  'orestes',
#  'barbi',
#  'hung',
#  'dequon',
#  'krystn',
#  'cassidy',
#  'fannye',
#  'tomie',
#  'arcola',
#  'vaibhav',
#  'onnie',
#  'aissatou',
#  'timmothy',
#  'dhillon',
#  'yeraldin',
#  'deen',
#  'kamily',
#  'wymon',
#  'harvel',
#  'erianna',
#  'rosebud',
#  'franki',
#  'kimble',
#  'willavene',
#  'sadaf',
#  'rayland',
#  'jemima',
#  'larry',
#  'kaaliyah',
#  'athziry',
#  'kongmeng',
#  'tesla',
#  'juliet',
#  'mitsue',
#  'marion',
#  'fitzgerald',
#  'airiel',
#  'haely',
#  'lashay',
#  'calissa',
#  'meilani',
#  'una',
#  'geanna',
#  'michael',
#  'kaycee',
#  'melton',
#  'lola',
#  'tracy',
#  'damiana',
#  'lovetta',
#  'diavion',
#  'elnatan',
#  'sammantha',
#  'jahaida',
#  'emin',
#  'eswin',
#  'bular',
#  'shloime',
# ...

# %%
valset.sort()

# %%
valset
# Out:
# ['aadit',
#  'aamina',
#  'aaric',
#  'aarna',
#  'aaryan',
#  'aayat',
#  'abagail',
#  'abaigeal',
#  'abbagail',
#  'abbigail',
#  'abdalla',
#  'abdo',
#  'abdulahi',
#  'abdullah',
#  'abelina',
#  'abigaelle',
#  'abilene',
#  'abundio',
#  'acen',
#  'adalyn',
#  'addam',
#  'addisen',
#  'adelbert',
#  'adonis',
#  'adrea',
#  'adrianne',
#  'agatha',
#  'ahad',
#  'ahan',
#  'ahliyah',
#  'aiden',
#  'aidric',
#  'aiesha',
#  'ailene',
#  'airiel',
#  'aissatou',
#  'ajaysia',
#  'akeel',
#  'akshaya',
#  'akshita',
#  'alaiyah',
#  'alassane',
#  'alayshia',
#  'albert',
#  'albie',
#  'aldahir',
#  'aldair',
#  'alejandr',
#  'alek',
#  'alessandra',
#  'alexis',
#  'alexxus',
#  'alfons',
#  'alfretta',
#  'algerd',
#  'alianna',
#  'alishba',
#  'aliza',
#  'allah',
#  'allard',
#  'allisha',
#  'almena',
#  'almon',
#  'alonzo',
#  'aloys',
#  'alston',
#  'alyissa',
#  'alysha',
#  'alyshia',
#  'alysia',
#  'alyze',
#  'alyzea',
#  'ama',
#  'amal',
#  'amalie',
# ...

# %%
with open("../.data/nlp/validation_corpus.txt", 'w') as f:
    for word in valset:
        f.write(word+"\n")

# %%
"kyle" in trainset
# Out:
# True
